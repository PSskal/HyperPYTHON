# %% [markdown]
# ### Problema 1 (2 ptos.) :
#
# Dado el código de la celda de abajo, complete las instrucciones del bloque *with* de tal manera que se lean los datos del archivo *data.txt* y en base a ello muestre la cantidad de números múltiplos de 5 presentes.

# %%
from random import randint
cont = 0

with open("data.txt") as file:
    while True:
        num = file.readline()
        if num:
            if int(num)%5==0:
                cont+= 1
        else:
            break

print("Cantidad de numeros múltiplos de 5 del archivo:",cont)
# Out:
# Cantidad de numeros múltiplos de 5 del archivo: 101

# %% [markdown]
# ### Problema 2 (2 ptos.) :
#
# Dado el código de la celda de abajo, complete las instrucciones dentro del *for* de tal manera que se almacenen en el diccionario *data*, 6 elementos. Cada elemento tendrá como llave un número aleatorio entero generado en el intervalo [2000,8000] y como valor la tercera cifra del número
#
# Por ejemplo, el diccionario *data* podría ser:
#
#      {7080: 8, 2798: 9, 6797: 9, 2632: 3, 3477: 7, 2827: 2}

# %%
from random import randint

data = {}


for i in range(1,7):
    


print(data)
# Out:
# {1: 2154, 2: 4902, 3: 4452, 4: 3179, 5: 3856, 6: 3895}

# %% [markdown]
# ### Problema 3 (3 ptos.) :
#
# Complete el código de la celda de abajo de tal manera que se pueda graficar la siguiente figura:
#
# ![imv2.png](attachment:imv2.png)
#
# **Obs.:** Utilice las herramientas de *matplotlib* vistas en clase para la generación de la gráfica (los pares ordenados mostrados no se deben mostrar, solo es referencial)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot([7,13],[13,13],"-b")
plt.plot([7,10],[13,4],"-b")
plt.plot([10,13],[4,13],"-b")
plt.axis([0,14,0,14])
plt.grid()
plt.show()




plt.show()

# %% [markdown]
# ### Problema 4 (2 ptos.) :
#
# Dado el código de la celda de abajo, complete las instrucciones dentro del *for* de la función *creaConjuntos(n)* de tal manera que retorne una lista de *n* conjuntos, donde cada conjunto tendrá 5 números aleatorios generados en el intervalo [10,50]
#
# Por ejemplo, si la función se invoca como *print(creaConjuntos(3))*, la lista retornada podría ser:
#
#     [{44, 15, 50, 23, 26}, {43, 13, 16, 24, 31}, {40, 11, 16, 50, 25}]

# %%
from random import randint

def creaConjuntos(n):
    num = 6
    l = []
    li = []
    c = set()
    for i in range(1,n+1):
        while len(c) < num:
            li.append(randint(10,50))
            c = set(li)
        l.append(c)
            
    return l

print(creaConjuntos(3))
# Out:
# [{35, 36, 43, 45, 17, 22}, {35, 36, 43, 45, 17, 22}, {35, 36, 43, 45, 17, 22}]

# %% [markdown]
# ### Problema 5 (4 ptos.) :
#
# Dado el código de la celda de abajo, complete las instrucciones del bloque *with* de tal manera que se tabule la función:
#            \begin{equation}
#                f(x)=\frac{cos(x).x^3}{x^2 + 1}
#            \end{equation}
#
# Para el dominio de *x* perteneciente al intervalo [-7 , 7] (utilice 100 elementos para el dominio).
#
# **Obs.:** Utilice las herramientas de *numpy* vistas en clase para la creación de los arreglos de dominio y rango.
#
# Todos los valores de *x* y los respectivos valores de la tabulación deberán escribirse en el archivo *tabulación.csv* (en formato excel), respetando el
# siguiente formato:
#
#                            x     F(x)
#                            -     -
#                            -     -
#                            -     -
#                            -     -
#                            .     .
#                            .     .
#                            .     .
#                            .     .
#
# Finalmente, se deberá graficar la función *F(x)* vs *x*, usando el siguente formato:
#
#           - línea segmentada de color rojo
#           - cuadrícula en la gráfica
#           - título: "Función matemática"
#           - etiqueta (eje x): "dominio [x]"
#           - etiqueta (eje y): "rango [y]"
#           - marcadores tipo cuadrado, con color de fondo azúl.
#
# **Obs.:** Utilice las herramientas de *matplotlib* vistas en clase para la generación de la gráfica

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
x = np.linspace(-7,7,100)
y = (np.cos(x)*x**3)/(x**2+1)

data = dict(zip(x,y))

with open("tabulacion.csv","w",newline="") as csv_file:
    
    writer= csv.writer(csv_file,delimiter=";")  
    writer.writerow(["x","F(x)"])
    for k,v in data.items():
        writer.writerow([k,v])

fig = plt.figure(figsize=(10,10))
plt.plot(x,y,"--rs")
plt.title("Función matemática")
plt.xlabel("dominio [x]")
plt.ylabel("rango [y]")

plt.grid()
plt.show()

# %% [markdown]
# ### Problema 6 (4 ptos.) :
#
# Complete el código de la celda de abajo de tal manera que permita construir la clase *Prueba*, la cual definirá a cualquier objeto instanciado a través del atributo público *V*. La clase deberá controlar que al atributo *V* solo se le asigne valor numérico (entero o float) y distinto de cero, de lo contrario se genererán las excepciones de tipo o valor correspondiente. La impresión (representación) de cualquier objeto deberá respetar el formato "Prueba[V:x]".
#
# La clase deberá definir la operación obj1%obj2 (donde obj1 y obj2 representan a objetos de la clase a construir) que dará como resultado otro objeto de la misma clase cuyo atributo será igual a:  $2.V_1^2 + 3.V_2^3$ ($V_1$ y $V_2$ son los atributos de obj1 y obj2)
#
# **Obs.:** En python cuando se ejecuta la operación % entre 2 objetos, se llama implícitamente al método mágico **__mod__**

# %%
class Prueba:
    
    def __init__(self, V=1):
        self.V = V 
        
    def __repr__(self):
        return "objeto:[V:{}]".format(self.V)
        
    @property
    def V(self):
        return self.__V
    
    @V.setter
    def V(self,val):
        if isinstance(val,float) or isinstance(val,int):
            if val>0:
                self.__V = val
            else:
                raise ValueError("V debe ser positivo")
        else:
            raise TypeError("V debe ser int o float")
            
    def __mod__(self,other):
        return Prueba((2*(self.V**2))+(3*(other.V**3)))

# %%
#comprobación de la clase:
obj1 = Prueba(V=10)
obj2 = Prueba(V=3.5)

print(obj1,obj2) #deberia salir: Prueba[V:10] Prueba[V:3.5]

#comprobación de la clase:
obj1 = Prueba(V=10)
obj2 = Prueba(V=3.5)

print(obj1,obj2) #deberia salir: Prueba[V:10] Prueba[V:3.5]
#comprobación de la clase:
obj1 = Prueba(V=10)
obj2 = Prueba(V=3.5)

print(obj1,obj2) #deberia salir: Prueba[V:10] Prueba[V:3.5]

obj1.V = 10
obj2.V = -2.5
print(obj1.V, obj2.V)  #debería salir: 10 -2.5

obj3 = obj1%obj2
print("el valor de obj3: ",obj3) #debería salir: Prueba[V:153.125]

#obj1.V = 0  #debe salir excepción de valor
#obj2.V = "UPC"  #debe salir excepción de tipo
# Out:
# objeto:[V:10] objeto:[V:3.5]
# objeto:[V:10] objeto:[V:3.5]
# objeto:[V:10] objeto:[V:3.5]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 19>()
#      16 print(obj1,obj2) #deberia salir: Prueba[V:10] Prueba[V:3.5]
#      18 obj1.V = 10
# ---> 19 obj2.V = -2.5
#      20 print(obj1.V, obj2.V)  #debería salir: 10 -2.5
#      22 obj3 = obj1%obj2
#
# Input In [2], in Prueba.V(self, val)
#      17         self.__V = val
#      18     else:
# ---> 19         raise ValueError("V debe ser positivo")
#      20 else:
#      21     raise TypeError("V debe ser int o float")
#
# ValueError: V debe ser positivo

# %% [markdown]
# ### Problema 7 (3 ptos.) :
#
# Complete el código de la celda de abajo de tal manera que permita generar una matriz de 2x7, cuyos valores serán números aleatorios enteros generados en el rango [5,25], luego de ello se generá un arreglo unidimensional (*arr1*) que almacenará la raíz cuadrada de todos los valores de la primera fila de la matriz y luego otro arreglo unidimensional (*arr2*) que almacenará todos los valores de la segunda fila pero restados con 4
#
# Por ejemplo, si la matriz original fuese:
#
#              [[25 13  8 19 13 15 15]
#               [22 23 22 13 18 10  8]]
#
# Los arreglos unidimensionales serían:
#
#     arreglo 1:  [5.  3.60555128 2.82842712 4.35889894 3.60555128
#                  3.87298335   3.87298335]
#     arreglo 2:  [18 19 18  9 14  6  4]
#
# **Obs.:** Utilice las herramientas de *numpy* vistas en clase para la creación de los arreglos.
# **Sugerencia:** Recuerde que a una matriz también se le puede aplicar la técnica del index-slicing

# %%
import numpy as np

#generacíón de la matriz original:
matriz = np.random.randint(5,25,(2,7)) #(use solo una instruccion)
print("matriz original: \n" ,matriz)

#creación de arreglos unidimensionales:
arr1 =np.sqrt(matriz)#(use solo una instruccion)
print("\narreglo 1: ",arr1)
arr2 =matriz-4 #(use solo una instruccion)
print("arreglo 2: ",arr2)
# Out:
# matriz original:
#  [[11 20 18  7  5 20 19]
#  [11  7  7 11 12  9 18]]
#
# arreglo 1:  [[3.31662479 4.47213595 4.24264069 2.64575131 2.23606798 4.47213595
#   4.35889894]
#  [3.31662479 2.64575131 2.64575131 3.31662479 3.46410162 3.
#   4.24264069]]
# arreglo 2:  [[ 7 16 14  3  1 16 15]
#  [ 7  3  3  7  8  5 14]]

# %%
import numpy as np

#generacíón de la matriz original:
matriz = np.random.randint(5,25,(2,7)) #(use solo una instruccion)
print("matriz original: \n" ,matriz)

#creación de arreglos unidimensionales:
arr1 #(use solo una instruccion)
#print("\narreglo 1: ",arr1)
#arr2 = #(use solo una instruccion)
print("arreglo 2: ",arr2)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__wrapped__',
#  '_implementation']
